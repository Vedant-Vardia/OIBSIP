# %% [markdown]
#  <h1 style='text-align: center;'>Unemployment Analysis (Task-2)</h1>

# %% [markdown]
# ### Importing Libraries & Nessasary Functions

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import datetime as dt
import calendar

# %% [markdown]
# #### Removing Warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Importing Data

# %%
df = pd.read_csv("Unemployment_Rate_upto_11_2020.csv")
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %% [markdown]
# #### Checking For Null Values.

# %%
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %% [markdown]
# #### Renaming 'Region' to 'State' and 'Region.1' to 'Region'

# %%
df=df.rename(columns={df.columns[0]:"State",df.columns[6]:"Region"})
df.head()
# Out:
#             State         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region  \
# 0             16635535                                     41.02  South
# 1             16545652                                     40.90  South
# 2             15881197                                     39.18  South
# 3             11336911                                     33.10  South
# 4             12988845                                     36.46  South
#
#    longitude  latitude
# 0    15.9129     79.74
# 1    15.9129     79.74
# ...

# %%
df['State'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)

# %% [markdown]
# #### Checking No of States & Data on each state

# %%
df.groupby("State").size()
# Out:
# State
# Andhra Pradesh      10
# Assam               10
# Bihar               10
# Chhattisgarh        10
# Delhi               10
# Goa                 10
# Gujarat             10
# Haryana             10
# Himachal Pradesh    10
# Jammu & Kashmir      9
# Jharkhand           10
# Karnataka           10
# Kerala              10
# Madhya Pradesh      10
# Maharashtra         10
# Meghalaya           10
# Odisha              10
# Puducherry          10
# Punjab              10
# Rajasthan           10
# Sikkim               8
# Tamil Nadu          10
# Telangana           10
# Tripura             10
# Uttar Pradesh       10
# Uttarakhand         10
# West Bengal         10
# dtype: int64

# %% [markdown]
# #### Checking The no of Regions

# %%
df.groupby("Region").size()
# Out:
# Region
# East         40
# North        79
# Northeast    38
# South        60
# West         50
# dtype: int64

# %% [markdown]
# #### Using date to find the Month

# %%
df['Date']=pd.to_datetime(df[' Date'],dayfirst=True)
df['Month']=df['Date'].dt.month
df['Month_int']=df["Month"].apply(lambda x:int(x))
df['Month']=df['Month_int'].apply(lambda x:calendar.month_abbr[x])
df.head()
# Out:
#             State         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region  \
# 0             16635535                                     41.02  South
# 1             16545652                                     40.90  South
# 2             15881197                                     39.18  South
# 3             11336911                                     33.10  South
# 4             12988845                                     36.46  South
#
#    longitude  latitude       Date Month  Month_int
# ...

# %%
df.groupby("Month").size()
# Out:
# Month
# Apr    26
# Aug    27
# Feb    26
# Jan    26
# Jul    27
# Jun    27
# Mar    27
# May    27
# Oct    27
# Sep    27
# dtype: int64

# %% [markdown]
# ## Estimated Employment Rate

# %%
fig=px.bar(df,x='Region',y=' Estimated Labour Participation Rate (%)',color='State'
           ,title="Monthly Employment(Region-Wise)",animation_frame="Month",template='plotly')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>                            <div id="b33d0eb2-ecc0-43f6-90b0-8386fdb139f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b33d0eb2-ecc0-43f6-90b0-8386fdb139f4")) {                    Plotly.newPlot(                        "b33d0eb2-ecc0-43f6-90b0-8386fdb139f4",                        [{"alignmentgroup":"True","hovertemplate":"State=Andhra Pradesh<br>Month=Jan<br>Region=%{x}<br> Estimated Labour Participation Rate (%)=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["South"],"xaxis":"x","y":[41.02],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=Ass
# ...

# %% [markdown]
# ## Unemployment rate (Region-Wise)

# %%
fig=px.bar(df,x='Region',y=' Estimated Unemployment Rate (%)',color='State',
           title="Monthly Unemployment Rate ",animation_frame='Month',template='plotly')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>                            <div id="b8f472b2-8485-4093-90fc-4a3c2301645e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8f472b2-8485-4093-90fc-4a3c2301645e")) {                    Plotly.newPlot(                        "b8f472b2-8485-4093-90fc-4a3c2301645e",                        [{"alignmentgroup":"True","hovertemplate":"State=Andhra Pradesh<br>Month=Jan<br>Region=%{x}<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["South"],"xaxis":"x","y":[5.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=Assam<br>Mon
# ...

# %% [markdown]
# # Unemployment Rate (State-Wise)

# %%
fig = px.box(df,x='State',y=' Estimated Unemployment Rate (%)',
             color='State',title='Estimated Unemployment rate',
             template='plotly')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>                            <div id="6371c52f-c184-4e21-a8fb-7142d40f09b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6371c52f-c184-4e21-a8fb-7142d40f09b6")) {                    Plotly.newPlot(                        "6371c52f-c184-4e21-a8fb-7142d40f09b6",                        [{"alignmentgroup":"True","hovertemplate":"State=%{x}<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa"},"name":"Andhra Pradesh","notched":false,"offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"x":["Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh"],"x0":" ","xaxi
# ...

# %%
fig=px.bar(df,x='State',y=' Estimated Unemployment Rate (%)',color='Region'
           ,title="Monthly Unemployment Rate(State-Wise)",animation_frame="Month",template='plotly')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>                            <div id="d0c73315-5212-4ae0-8efc-29094d72e44c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0c73315-5212-4ae0-8efc-29094d72e44c")) {                    Plotly.newPlot(                        "d0c73315-5212-4ae0-8efc-29094d72e44c",                        [{"alignmentgroup":"True","hovertemplate":"Region=South<br>Month=Jan<br>State=%{x}<br> Estimated Unemployment Rate (%)=%{y}<extra></extra>","legendgroup":"South","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"South","offsetgroup":"South","orientation":"v","showlegend":true,"textposition":"auto","x":["Andhra Pradesh","Karnataka","Kerala","Puducherry","Tamil Nadu","Telangana"],"xaxis":"x","y":[5.48,2.86,5.31,0.58,1.57,5.49],"yaxis":"y","type":"bar"},{"a
# ...

# %% [markdown]
# ## Complete Unemployment Rate Graph

# %%
x=df[['State','Region',' Estimated Unemployment Rate (%)']]
fig=px.sunburst(x,path=['Region','State'],
               values=' Estimated Unemployment Rate (%)',
               width=800,height=800,color_continuous_scale="YlGnBl",
               title="Unemployment Rate In India")
fig.show()
# Out:
# <div>                            <div id="dedba80f-08e5-459c-8ea9-c5957d98b675" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dedba80f-08e5-459c-8ea9-c5957d98b675")) {                    Plotly.newPlot(                        "dedba80f-08e5-459c-8ea9-c5957d98b675",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br> Estimated Unemployment Rate (%)=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["South/Andhra Pradesh","Northeast/Assam","East/Bihar","West/Chhattisgarh","North/Delhi","West/Goa","West/Gujarat","North/Haryana","North/Himachal Pradesh","North/Jammu & Kashmir","East/Jharkhand","South/Karnataka","South/Kerala","West/Madhya Pradesh","West/Maharashtra",
# ...
